# %% [markdown]
# # Web Scraping Job Vacancies

# %% [markdown]
# ## Introduction
#
# In this project, we'll build a web scraper to extract job listings from a popular job search platform. We'll extract job titles, companies, locations, job descriptions, and other relevant information.
#
# Here are the main steps we'll follow in this project:
#
# 1. Setup our development environment
# 2. Understand the basics of web scraping
# 3. Analyze the website structure of our job search platform
# 4. Write the Python code to extract job data from our job search platform
# 5. Save the data to a CSV file
# 6. Test our web scraper and refine our code as needed
#
# ## Prerequisites
#
# Before starting this project, you should have some basic knowledge of Python programming and HTML structure. In addition, you may want to use the following packages in your Python environment:
#
# - requests
# - BeautifulSoup
# - csv
# - datetime
#
# These packages should already be installed in Coursera's Jupyter Notebook environment, however if you'd like to install additional packages that are not included in this environment or are working off platform you can install additional packages using `!pip install packagename` within a notebook cell such as:
#
# - `!pip install requests`
# - `!pip install BeautifulSoup`

# %% [markdown]
# ## Step 1: Importing Required Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://weworkremotely.com/"
response = requests.get(url)
soup = BeautifulSoup(response.content,'html.parser')
html = soup.prettify()

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <script>
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"f7ae79e7ca","applicationID":"192262830","transactionName":"d1gPFhEMXVVWQxwMDVZETgsNB1RB","queueTime":2,"applicationTime":801,"agent":""}
#   </script>
#   <script>
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"f7ae79e7ca",applicationID:"192262830"};;/*! For license information please see nr-loader-rum-1.283.2.min.js.LICENSE.txt */
# (()=>{var e,t,r={122:(e,t,r)=>{"use strict";r.d(t,{a:()=>i});var n=r(944);function i(e,t){try{if(!e||"object"!=typeof e)return(0,n.R)(3);if(!t||"object"!=typeof t)return(0,n.R)(4);const r=Object.create(Object.getPrototypeOf(t),Object.getOwnPropertyDescriptors(t)),o=0===Object.keys(r).length?e:r;for(let a in o)if(void 0!==e[a])try{if(null===e[a]){r[a]=null;continue}Array.isArray(e[a])&&Array.isArray(t[a])?r[a]=Array.from(new Set([...e[a],...t[a]])):"object"==typeof e[a]&&"object"==typeof t[a]?r[a]=i(e[a],t[a]):r[a]=e[a]}catch(e){(0,n.R)(1,e)}return r}catch(e){(0,n.R)(2,e)}}},555:(e,t,r)=>{"use strict";r.d(t,{Vp:()=>c,fn:()=>s,x1:()=>u});var n=r(384),i=r(122);const o={beacon:n.NT.beacon,errorBeacon:n.NT.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){try{const t=c(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}function c(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function u(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.a)(t,o);const r=(0,n.nY)(e);r&&(r.info=a[e])}},217:(e,t,r)=>{"use strict";r.d(t,{D0:()=>m,gD:()=>v,xN:()=>h});r(860).K7.genericEvents;const n="experimental.marks",i="experimental.measures",o="experimental.resources",a=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var s=r(614),c=r(944),u=r(384),l=r(122);const d="[data-nr-mask]",f=()=>{const e={feature_flags:[],experimental:{marks:!1,measures:!1,resources:!1},mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{ajax:{deny_list:void 0,block_internal:!0,enabled:!0,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},get feature_flags(){return e.feature_flags},set feature_flags(t){e.feature_flags=t},generic_events:{enabled:!0,autoStart:!0},harvest:{interval:30},jserrors:{enabled:!0,autoStart:!0},logging:{enabled:!0,autoStart:!0},metrics:{enabled:!0,autoStart:!0},obfuscate:void 0,page_action:{enabled:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,autoStart:!0},performance:{get capture_marks(){return e.feature_flags.includes(n)||e.experimental.marks},set capture_marks(t){e.experimental.marks=t},get capture_measures(){return e.feature_flags.includes(i)||e.experimental.measures},set capture_measures(t){e.experimental.measures=t},capture_detail:!0,resources:{get enabled(){return e.feature_flags.includes(o)||e.experimental.resources},set enabled(t){e.experimental.resources=t},asset_types:[],first_party_domains:[],ignore_newrelic:!0}},privacy:{cookies_enabled:!0},proxy:{assets:void 0,beacon:void 0},session:{expiresMs:s.wk,inactiveMs:s.BB},session_replay:{autoStart:!0,enabled:!1,preload:!1,sampling_rate:10,error_sampling_rate:100,collect_fonts:!1,inline_images:!1,fix_stylesheets:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){a(t)?e.mask_selector="".concat(t,",").concat(d):""===t||null===t?e.mask_selector=d:(0,c.R)(5,t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){a(t)?e.block_selector+=",".concat(t):""!==t&&(0,c.R)(6,t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,c.R)(7,t)}},session_trace:{e ...
#   </script>
#   <meta content="width=device-width" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/chosen/1.8.7/chosen.min.css" integrity="sha512-yVvxUQV0QESBt1SyZbNJMAwyKvFTLMyXSyBHDO4BG5t7k/Lw34tyqlSDlKIrIENIzCl+RVUNjmCPG+V/GMesRw==" rel="stylesheet"/>
#   <link href="https://weworkremotely.com/assets/application-88f719eff2c409438cb547e6f0c975ca8226c1befa3d2a85b6a9d328253d0c4b.css" media="screen" rel="stylesheet"/>
#   <link href="https://weworkremotely.com/assets/print-10e584452a44db0451511ba6325ac447d59be199e4fb1ad80e873eeb7768ba74.css" media="print" rel="stylesheet"/>
#   <title>
#    We Work Remotely: Remote jobs in design, programming, marketing and more
#   </title>
#   <meta content="We Work Remotely" name="apple-mobile-web-app-title">
#    <meta content="We Work Remotely" name="application-name"/>
#    <meta content="We Work Remotely: Remote jobs in design, programming, marketing and more" property="og:title"/>
#    <meta content="We Work Remotely: Remote jobs in design, programming, marketing and more" property="title"/>
#    <meta content="We Work Remotely" property="og:site_name"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="@weworkremotely" name="twitter:site"/>
#    <meta content="https://weworkremotely.com/assets/wwr-social-fd7d545c56e975b65fae9cf49346aac95a8cdb4774b2c269af89ac8993141380.png" name="twitter:image"/>
#    <meta content="Find the most qualified people in the most unexpected places: Hire remote! We Work Remotely is the best place to find and list remote jobs that aren't restricted by commutes or a particular geographic area. Browse thousands of remote work jobs today." name="description">
#     <meta content="Find the most qualified people in the most unexpected places: Hire remote! We Work Remotely is the best place to find and list remote jobs that aren't restricted by commutes or a particular geographic area. Browse thousands of remote work jobs today." property="og:description"/>
#     <meta content="https://weworkremotely.com/assets/wwr-social-fd7d545c56e975b65fae9cf49346aac95a8cdb4774b2c269af89ac8993141380.png" property="og:image"/>
#     <meta content="1639030506338400" property="fb:app_id"/>
#     <script type="application/ld+json">
#      {
#     "@context": "http://schema.org",
#     "@type": "Organization",
#     "name": "We Work Remotely",
#     "url": "https://weworkremotely.com",
#     "logo": "https://weworkremotely.com/assets/wwr-social-fd7d545c56e975b65fae9cf49346aac95a8cdb4774b2c269af89ac8993141380.png",
#     "sameAs": [
#       "https://twitter.com/weworkremotely"
#     ]
#   }
#     </script>
#     <script type="application/ld+json">
#      {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "name": "We Work Remotely",
#     "url": "https://weworkremotely.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://weworkremotely.com/jobs/search?term={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
#   }
#     </script>
#     <link href="/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#     <link href="/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#     <link href="/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#     <link href="/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#     <link href="/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#     <link href="/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#     <link href="/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#     <link href="/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#     <link href="/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#     <link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#     <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#     <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#     <link href="/manifest.json" rel="manifest"/>
#     <meta content="#212529000" name="msapplication-TileColor"/>
#     <meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/>
#     <meta content="#212529000" name="theme-color"/>
#     <meta content="authenticity_token" name="csrf-param">
#      <meta content="T6Z+IaAzIV+vqFORhhWW2Nakyvx8CY9UvetjA0TaGbtah8Bp1z/A5Jvz3Us6Ex8jNiTT+eKcYDp5Kt4+ceqzKw==" name="csrf-token">
#       <link href="https://weworkremotely.com/remote-jobs.rss" rel="alternate" title="RSS" type="application/rss+xml">
#        <link href="https://weworkremotely.com/" rel="canonical">
#         <script>
#          window._tfa = window._tfa || [];
#   window._tfa.push({notify: 'event', name: 'page_view', id: 1219634});
#   !function (t, f, a, x) {
#          if (!document.getElementById(x)) {
#             t.async = 1;t.src = a;t.id=x;f.parentNode.insertBefore(t, f);
#          }
#   }(document.createElement('script'),
#   document.getElementsByTagName('script')[0],
#   '//cdn.taboola.com/libtrc/unip/1219634/tfa.js',
#   'tb_tfa_script');
#         </script>
#         <noscript>
#          <img height="0" src="//trc.taboola.com/1219634/log/3/unip?en=page_view" style="display:none" width="0"/>
#         </noscript>
#         <script>
#          (function(w,r){w._rwq=r;w[r]=w[r]||function(){(w[r].q=w[r].q||[]).push(arguments)}})(window,'rewardful');
#         </script>
#         <script async="" data-rewardful="15c623" src="https://r.wdfl.co/rw.js">
#         </script>
#         <script>
#          (function(h,o,t,j,a,r){
#       h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#       h._hjSettings={hjid:2385808,hjsv:6};
#       a=o.getElementsByTagName('head')[0];
#       r=o.createElement('script');r.async=1;
#       r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#       a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#         </script>
#         <script async="" src="https://script.tapfiliate.com/tapfiliate.js">
#         </script>
#         <script>
#          (function(t,a,p){t.TapfiliateObject=a;t[a]=t[a]||function(){
#     (t[a].q=t[a].q||[]).push(arguments)}})(window,'tap');
#
#     tap('create', '26060-8d5b8b', { integration: "stripe" });
#     tap('detect');
#         </script>
#         <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-HFDNXM8BDG">
#         </script>
#         <script>
#          window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', "G-HFDNXM8BDG");
#         </script>
#         <script>
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-P367CJ34');
#         </script>
#         <script>
#          //<![CDATA[
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#     ga('create', 'UA-24041469-10', 'auto');
#     ga('require', 'GTM-WFH9SJ4');
#     ga('send', 'pageview');
# //]]>
#         </script>
#         <script>
#          //<![CDATA[
# (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#    h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#    (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#    })(window,document.documentElement,'async-hide','dataLayer',4000,
#    {'GTM-WFH9SJ4':true});
# //]]>
#         </script>
#         <script>
#          //<![CDATA[
# if(window.ga != undefined){ga('send', 'pageview');}
# //]]>
#         </script>
#         <script crossorigin="anonymous" src="https://kit.fontawesome.com/db1101d7e0.js">
#         </script>
#         <script src="https://js.stripe.com/v3/">
#         </script>
#         <script async="" defer="" src="https://scripts.simpleanalyticscdn.com/latest.js">
#         </script>
#         <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-2204502733968137">
#         </script>
#         <script async="" class="ct_clicktrue_72473" data-ch="cheq4ppc" src="https://ob.andstarsbuilding.com/i/6263e0fb95e2bf0124162360283ac7bb.js">
#         </script>
#        </link>
#       </link>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="home main">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P367CJ34" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <noscript>
#    <iframe height="0" src="https://obs.andstarsbuilding.com/ns/6263e0fb95e2bf0124162360283ac7bb.html?ch=cheq4ppc" style="display:none" width="0">
#    </iframe>
#   </noscript>
#   <div class=".container--wwr">
#    <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/css/bootstrap.min.css" integrity="sha384-4bw+/aepP/YC94hEpVNVgiZdgIC5+VKNBQNGCHeKRQN+PtmoHDEXuppvnDJzQIu9" rel="stylesheet"/>
#    <script crossorigin="anonymous" integrity="sha256-/JqT3SQfawRcv/BIHPThkBvs0OEvtFFmqPF/lYI/Cxo=" src="https://code.jquery.com/jquery-3.7.1.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha384-I7E8VVD/ismYTF4hNIPjVp/Zjvgyol6VFvRkX/vR+Vc4jQkC+hVqc2pM8ODewa9r" src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.11.8/dist/umd/popper.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha384-Rx+T1VzGupg4BHQYs2gCW9It+akI2MM/mndMCy36UVfodzcJcF0GGLxZIzObiEfa" src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/js/bootstrap.min.js">
#    </script>
#    <header id="nav-header">
#     <section id="header-top-bar">
#      <a href="/">
#       <img alt="we work remotely" id="logo" src="https://weworkremotely.com/assets/LogoV1-61d4e31f77003b03dcaefb766a2347f12d33fb2d6147c6637f89ca7bcd9bfecd.svg"/>
#      </a>
#      <nav class="top">
#       <div class="dropdownBackground">
#        <span class="arrow">
#        </span>
#       </div>
#       <ul class="wwr__nav d-flex align-items-center">
#        <li class="magic__nav">
#         <a href="#">
#          Jobs
#          <i class="fa fa-chevron-down ms-1">
#          </i>
#         </a>
#         <ul class="dropdown jobs">
#          <li>
#           <a href="/top-trending-remote-jobs">
#            Top Trending Remote Jobs
#            <span class="new">
#             New!
#            </span>
#           </a>
#          </li>
#          <hr/>
#          <li>
#           <a href="/">
#            All Jobs
#           </a>
#          </li>
#          <li class="dropdown-programming">
#           <a href="#" id="programming-active">
#            Programming
#            <i class="fa fa-chevron-down">
#            </i>
#           </a>
#          </li>
#          <div class="dropdown-container">
#           <li>
#            <a href="/categories/remote-full-stack-programming-jobs#job-listings">
#             Full-Stack Programming
#            </a>
#           </li>
#           <li>
#            <a href="/categories/remote-front-end-programming-jobs#job-listings">
#             Front-End Programming
#            </a>
#           </li>
#           <li>
#            <a href="/categories/remote-back-end-programming-jobs#job-listings">
#             Back-End Programming
#            </a>
#           </li>
#          </div>
#          <li>
#           <a href="/categories/remote-design-jobs#job-listings">
#            Design
#           </a>
#          </li>
#          <li>
#           <a href="/categories/remote-devops-sysadmin-jobs#job-listings">
#            Devops and Sysadmin
#           </a>
#          </li>
#          <li>
#           <a href="/categories/remote-management-and-finance-jobs#job-listings">
#            Management and Finance
#           </a>
#          </li>
#          <li>
#           <a href="/categories/remote-product-jobs">
#            Product
#           </a>
#          </li>
#          <li>
#           <a href="/categories/remote-customer-support-jobs#job-listings">
#            Customer Support
#           </a>
#          </li>
#          <li>
#           <a href="/categories/remote-sales-and-marketing-jobs#job-listings">
#            Sales and Marketing
#           </a>
#          </li>
#          <li>
#           <a href="/categories/all-other-remote-jobs#job-listings">
#            All Other Jobs
#           </a>
#          </li>
#          <hr/>
#          <li>
#           <a href="/remote-full-time-jobs#job-listings">
#            Full-Time
#           </a>
#          </li>
#          <li>
#           <a href="/remote-contract-jobs#job-listings">
#            Contract
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="magic__nav">
#         <a href="#">
#          Community
#          <i class="fa fa-chevron-down ms-1">
#          </i>
#         </a>
#         <ul class="dropdown community">
#          <li>
#           <a href="/blog">
#            Blog
#           </a>
#          </li>
#          <li>
#           <a href="/the-remote-show-podcast">
#            Podcast
#           </a>
#          </li>
#          <li>
#           <a href="/remote-work-trends">
#            Remote Work Trends
#           </a>
#          </li>
#          <hr/>
#          <li>
#           <a href="/blog-categories/events" target="_blank">
#            Events
#           </a>
#          </li>
#          <hr/>
#          <li class="d-flex justify-content-between community__socials">
#           <a href="https://twitter.com/weworkremotely/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-twitter&amp;utm_medium=nav-network-twitter" target="_blank">
#            <i class="fa-brands fa-twitter fa-2x">
#            </i>
#           </a>
#           <a href="https://www.instagram.com/weworkremotelycom/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-fb&amp;utm_medium=nav-network-fb" target="_blank">
#            <i class="fa-brands fa-square-instagram fa-2x">
#            </i>
#           </a>
#           <a href="https://www.linkedin.com/company/18527028/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-linkedin&amp;utm_medium=nav-network-linkedin" target="_blank">
#            <i class="fa-brands fa-linkedin fa-2x">
#            </i>
#           </a>
#           <a href="https://www.facebook.com/weworkremotely/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-fb&amp;utm_medium=nav-network-fb" target="_blank">
#            <i class="fa-brands fa-square-facebook fa-2x">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="magic__nav">
#         <a href="#">
#          Find work
#          <i class="fa fa-chevron-down ms-1">
#          </i>
#         </a>
#         <ul class="dropdown resources">
#          <li>
#           <a href="/top-remote-companies">
#            Top 100 Remote Companies
#           </a>
#          </li>
#          <li>
#           <a href="/top-remote-job-searches">
#            Top Remote Job Searches
#           </a>
#          </li>
#          <li>
#           <a href="/remote-jobs/search">
#            Advanced Job Search
#            <span class="new">
#             New!
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="/career-services/job-copilot">
#            Automate your Job Search
#            <span class="new">
#             New!
#            </span>
#           </a>
#          </li>
#          <hr/>
#          <li>
#           <a href="/job-seeker-faq">
#            FAQ - Job Seekers
#           </a>
#          </li>
#          <hr/>
#          <li>
#           <a href="/remote-job-rss-feed">
#            RSS Feed
#           </a>
#          </li>
#          <li>
#           <a href="/blog-categories/remote-work-resources">
#            Remote Work Resources
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="magic__nav">
#         <a href="#">
#          Career Services
#          <i class="fa fa-chevron-down ms-1">
#          </i>
#         </a>
#         <ul class="dropdown resources">
#          <li>
#           <a href="/career-services/resume-reviewer">
#            Resume Review Service
#            <span class="new">
#             New!
#            </span>
#           </a>
#          </li>
#          <li>
#           <a href="/career-services/job-copilot">
#            Automate your Job Search
#            <span class="new">
#             New!
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="magic__nav">
#         <a href="#">
#          Find talent
#          <i class="fa fa-chevron-down ms-1">
#          </i>
#         </a>
#         <ul class="dropdown resources" id="nav">
#          <li>
#           <a href="/remote-work-hiring-guide">
#            Remote Hiring Guide
#           </a>
#          </li>
#          <li>
#           <a href="/hire-remote-software-developers">
#            Hiring Remote Software Developers
#           </a>
#          </li>
#          <li>
#           <a href="/post-a-remote-job">
#            Why Choose WWR?
#           </a>
#          </li>
#          <hr/>
#          <li>
#           <a href="/frequently-asked-questions">
#            FAQ - Employers
#           </a>
#          </li>
#          <hr/>
#          <li>
#           <a href="/bundles?utm_source=wwr-nav" onclick="applyForPromotion()" target="_blank">
#            Save with Bundles
#            <i class="fa-regular fa-piggy-bank" style=" color: #212529 !important; font-size: 1rem;">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="search-bar-container">
#         <form accept-charset="UTF-8" action="/remote-jobs/search" class="search-container" id="wwr_search_form" method="get">
#          <i class="fa-solid fa-magnifying-glass" style="color: #ACBBC9 !important;">
#          </i>
#          <input id="search_term" name="term" placeholder="Search"/>
#         </form>
#        </li>
#        <li class="magic__nav">
#        </li>
#        <li class="btn-new-cta btn-new-nav cta-button">
#         <a href="/account/sign_in?utm_content=sign-in-cta&amp;utm_source=wwr-accounts-nav-top" id="sign-in-cta-nav">
#          Sign in
#         </a>
#        </li>
#        <li class="cta-button">
#         <a href="/remote-jobs/new?utm_source=wwr-accounts-nav-top" id="post-job-cta-nav">
#          Post a job
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </section>
#    </header>
#    <header id="mobile-header">
#     <nav class="nav-list d-flex">
#      <a class="nav-list__main-logo" href="/">
#       <img alt="we work remotely" id="logo" src="https://weworkremotely.com/assets/IsotypeV2-1ebe3dd57673f3e8d02b7490bc0faaef55d6a95d3a4aaf17298bd3ed503ae7fe.svg"/>
#      </a>
#      <div class="nav-list__btns-container">
#       <div class="btn-new-cta btn-new-nav cta-button">
#        <a href="/account/sign_in?utm_content=sign-in-employer-cta&amp;utm_source=wwr-accounts-nav-mobile" id="sign-in-cta-nav">
#         Sign in
#        </a>
#       </div>
#       <div id="nav-bar-btn">
#        <span class="bar">
#        </span>
#        <span class="bar">
#        </span>
#        <span class="bar bar-2">
#        </span>
#       </div>
#      </div>
#      <div class="mobile-menu">
#       <div class="mobile-menu__top">
#        <div class="search-bar-container">
#         <form accept-charset="UTF-8" action="/remote-jobs/search" class="search-container" id="wwr_search_form" method="get">
#          <i class="fa-solid fa-magnifying-glass fa-1x" style="color: #ACBBC9 !important;">
#          </i>
#          <input id="search_term" name="term" placeholder="Search"/>
#         </form>
#        </div>
#        <ul class="mobile-menu-links">
#         <li class="accordion-mov">
#          <div class="accordion-header">
#           Jobs
#           <i class="fa fa-chevron-down accordion-icon fa-1x">
#           </i>
#          </div>
#          <div class="accordion-content">
#           <ul>
#            <li>
#             <a href="/top-trending-remote-jobs">
#              Top Trending Remote Jobs
#             </a>
#             <span class="new">
#              New!
#             </span>
#            </li>
#            <li>
#             <a href="/">
#              All Jobs
#             </a>
#            </li>
#            <li class="accordion-mov inside">
#             <div class="accordion-header">
#              Programming
#              <i class="fa fa-chevron-down accordion-icon fa-1x">
#              </i>
#             </div>
#             <div class="accordion-content">
#              <ul>
#               <li>
#                <a href="/categories/remote-full-stack-programming-jobs#job-listings">
#                 Full-Stack Programming
#                </a>
#               </li>
#               <li>
#                <a href="/categories/remote-front-end-programming-jobs#job-listings">
#                 Front-End Programming
#                </a>
#               </li>
#               <li>
#                <a href="/categories/remote-back-end-programming-jobs#job-listings">
#                 Back-End Programming
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <li>
#             <a href="/categories/remote-design-jobs#job-listings">
#              Design
#             </a>
#            </li>
#            <li>
#             <a href="/categories/remote-devops-sysadmin-jobs#job-listings">
#              Devops and Sysadmin
#             </a>
#            </li>
#            <li>
#             <a href="/categories/remote-management-and-finance-jobs#job-listings">
#              Management and Finance
#             </a>
#            </li>
#            <li>
#             <a href="/categories/remote-product-jobs">
#              Product
#             </a>
#            </li>
#            <li>
#             <a href="/categories/remote-customer-support-jobs#job-listings">
#              Customer Support
#             </a>
#            </li>
#            <li>
#             <a href="/categories/remote-sales-and-marketing-jobs#job-listings">
#              Sales and Marketing
#             </a>
#            </li>
#            <li class="divisor">
#             <a href="/categories/all-other-remote-jobs#job-listings">
#              All Other Jobs
#             </a>
#            </li>
#            <li>
#             <a href="/remote-full-time-jobs#job-listings">
#              Full-Time
#             </a>
#            </li>
#            <li>
#             <a href="/remote-contract-jobs#job-listings">
#              Contract
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="accordion-mov">
#          <div class="accordion-header">
#           Community
#           <i class="fa fa-chevron-down accordion-icon fa-1x">
#           </i>
#          </div>
#          <div class="accordion-content">
#           <ul>
#            <li>
#             <a href="/blog">
#              Blog
#             </a>
#            </li>
#            <li>
#             <a href="/the-remote-show-podcast">
#              Podcast
#             </a>
#            </li>
#            <li class="divisor">
#             <a href="/remote-work-trends">
#              Remote Work Trends
#             </a>
#            </li>
#            <li class="divisor">
#             <a href="/blog-categories/events" target="_blank">
#              Events
#             </a>
#            </li>
#            <li class="d-flex justify-content-between divisor socials">
#             <a href="https://www.facebook.com/weworkremotely/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-fb&amp;utm_medium=nav-network-fb" target="_blank">
#              <i class="fa-brands fa-square-facebook fa-2x">
#              </i>
#             </a>
#             <a href="https://www.linkedin.com/company/18527028/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-linkedin&amp;utm_medium=nav-network-linkedin" target="_blank">
#              <i class="fa-brands fa-linkedin fa-2x">
#              </i>
#             </a>
#             <a href="https://www.instagram.com/weworkremotelycom/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-fb&amp;utm_medium=nav-network-fb" target="_blank">
#              <i class="fa-brands fa-square-instagram fa-2x">
#              </i>
#             </a>
#             <a href="https://twitter.com/weworkremotely/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-twitter&amp;utm_medium=nav-network-twitter" target="_blank">
#              <i class="fa-brands fa-x-twitter fa-2x">
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="accordion-mov">
#          <div class="accordion-header">
#           Find work
#           <i class="fa fa-chevron-down accordion-icon fa-1x">
#           </i>
#          </div>
#          <div class="accordion-content">
#           <ul>
#            <li>
#             <a href="/top-remote-companies">
#              Top 100 Remote Companies
#             </a>
#            </li>
#            <li>
#             <a href="/top-remote-job-searches">
#              Top Remote Job Searches
#             </a>
#            </li>
#            <li class="divisor">
#             <a href="/remote-jobs/search">
#              Advanced Job Search
#              <span class="new">
#               New!
#              </span>
#             </a>
#            </li>
#            <li>
#             <a href="/career-services/job-copilot">
#              Automate your Job Search
#              <span class="new">
#               New!
#              </span>
#             </a>
#            </li>
#            <li class="divisor">
#             <a href="/job-seeker-faq">
#              FAQ - Job Seekers
#             </a>
#            </li>
#            <li>
#             <a href="/remote-job-rss-feed">
#              RSS Feed
#             </a>
#            </li>
#            <li>
#             <a href="/blog-categories/remote-work-resources">
#              Remote Work Resources
#             </a>
#            </li>
#            <li class="divisor last">
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="accordion-mov">
#          <div class="accordion-header">
#           Career Services
#           <i class="fa fa-chevron-down accordion-icon fa-1x">
#           </i>
#          </div>
#          <div class="accordion-content">
#           <ul>
#            <li>
#             <a href="/career-services/resume-reviewer">
#              Resume Review Service
#              <span class="new">
#               New!
#              </span>
#             </a>
#            </li>
#            <li>
#             <a href="/career-services/job-copilot">
#              Automate your Job Search
#              <span class="new">
#               New!
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="accordion-mov">
#          <div class="accordion-header">
#           Find talent
#           <i class="fa fa-chevron-down accordion-icon fa-1x">
#           </i>
#          </div>
#          <div class="accordion-content">
#           <ul>
#            <li>
#             <a href="/remote-work-hiring-guide">
#              Remote Hiring Guide
#             </a>
#            </li>
#            <li>
#             <a href="/hire-remote-software-developers">
#              Hiring Remote Software Developers
#             </a>
#            </li>
#            <li class="divisor">
#             <a href="/post-a-remote-job">
#              Why Choose WWR?
#             </a>
#            </li>
#            <li>
#             <a href="/frequently-asked-questions">
#              FAQ - Employers
#             </a>
#            </li>
#            <li>
#             <a href="/bundles?utm_source=wwr-nav" onclick="applyForPromotion()" target="_blank">
#              Save with Bundles
#              <i class="fa-regular fa-piggy-bank" style=" color: #212529 !important; font-size: 2rem;">
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="btn mobile-menu__post-job-cta" id="post-job-cta-nav">
#        <a href="/remote-jobs/new?utm_content=post-job-cta&amp;utm_source=wwr-accounts-nav-mobile">
#         Post a job
#        </a>
#       </div>
#      </div>
#     </nav>
#     <div class="user-modal" id="userModal">
#      <div class="user-modal-content">
#       <i class="fa-solid fa-xmark close fa-2x">
#       </i>
#      </div>
#     </div>
#    </header>
#    <div class="user-modal" id="userModal">
#     <div class="user-modal-content">
#      <span class="close">
#       ×
#      </span>
#     </div>
#    </div>
#    <div class="content">
#     <div class="header-flash">
#     </div>
#     <script>
#      document.cookie = "state=; expires=Thu, 01 Jan 1970 00:00:00 UTC" + ";domain=" + window.location.hostname + ";path=/;"
#     </script>
#     <header alt="We Work Remotely: Remote jobs in design, programming, marketing and more" description="Find the most qualified people in the most unexpected places: Hire remote! We Work Remotely is the best place to find and list remote jobs that aren't restricted by commutes or a particular geographic area. Browse thousands of remote work jobs today." id="main-header" title="We Work Remotely: Remote jobs in design, programming, marketing and more.">
#      <div class="header-flash">
#       <script>
#        function closeButton() {
#     document.getElementById('close_flash').style.display = 'none';
#   }
#   function closeButtonError() {
#     document.getElementById('error_explanation').style.display = 'none';
#   }
#   function closeButtonFlashError() {
#     document.getElementById('close_error').style.display = 'none';
#   }
#       </script>
#      </div>
#      <script>
#       function ResetFilters() {
#     var url = window.location.href.split('?')[0];
#     setTimeout(function(){
#       window.location.href = url;
#     }, 100);
#   }
#      </script>
#      <div class="new-header" id="new-header">
#       <div class="new-header__jobs-counter">
#        <i class="new-header__jobs-counter__icon fa-sharp fa-regular fa-fire" style="color: #F03F3F;">
#        </i>
#        <p class="new-header__jobs-counter__number">
#         34,136
#         <span>
#          jobs posted
#         </span>
#        </p>
#       </div>
#       <h2 class="new-header__title">
#        The
#        <span>
#         largest
#        </span>
#        job board for remote jobs
#       </h2>
#       <div class="new-header__logo-container">
#        <p class="new-header__description">
#         For over a decade, WWR has been the #1 site for remote jobs, with 6M monthly visitors and the world's largest remote work community
#        </p>
#       </div>
#       <a class="new-header__post-job-cta" href="/remote-jobs/new">
#        Post a job for $299
#       </a>
#      </div>
#     </header>
#     <a class="anchor-offset" id="job-listings">
#      ・
#     </a>
#     <section id="banner-header">
#      <div class="trusted_banner">
#       <div id="trusted-text">
#        Trusted by the world's leading companies
#       </div>
#      </div>
#     </section>
#     <div class="jobs-container" id="job_list">
#      <a class="anchor-offset" id="job-listings">
#       ・
#      </a>
#      <section class="jobs" id="category-1">
#       <article>
#        <h2>
#         <a href="/categories/remote-design-jobs">
#          Design Jobs
#         </a>
#         <span class="latest_post">
#          Latest post about 18 hours ago
#         </span>
#         <a href="/categories/remote-design-jobs.rss">
#          <img class="feed" height="16" src="https://weworkremotely.com/assets/rss-feed-bac611a39b717b45766a28c96e549e1879df2786844a54f9c888ed89d64891a7.svg" width="16"/>
#         </a>
#        </h2>
#        <ul>
#         <li class="new-listing-container feature">
#          <div class="highlight-bar">
#          </div>
#          <div class="tooltip--flag-logo">
#           <a href="/company/cdata-virtuality">
#            <div alt="CData Virtuality is hiring a remote Senior Backend Developer SaaS at We Work Remotely." class="tooltip--flag-logo__flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0165/2445/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)">
#            </div>
#            <span class="tooltip--flag-logo__tooltiptext">
#             View Company Profile
#            </span>
#           </a>
#          </div>
#          <a href="/remote-jobs/cdata-virtuality-senior-backend-developer-saas-2">
#           <div class="new-listing paid-logo">
#            <div class="new-listing__header">
#             <h4 class="new-listing__header__title">
#              Senior Backend Developer SaaS
#             </h4>
#             <div class="new-listing__header__icons">
#              <p class="new-listing__header__icons__date">
#               <span class="new">
#                New
#               </span>
#              </p>
#              <img alt="Pin Icon" class="new-listing__header__icons__pinnedIcon" src="https://weworkremotely.com/assets/pin-new-listing-icon-5020930338642c85166c5dc90e0cc3b616195333121663c6dd985fe502f1466a.svg"/>
#             </div>
#            </div>
#            <p class="new-listing__company-name">
#             CData Virtuality
#             <img alt="Star Icon" class="lis-container__job__sidebar__companyDetails__info__title__icon" src="https://weworkremotely.com/assets/company-name-new-listing-icon-899e2740e328cbba3a77a60510295001f767aae8cde67202b9157ed79be205cc.svg"/>
#            </p>
#            <p class="new-listing__company-headquarters">
#             Leipzig
#             <i class="fa-solid fa-location-dot">
#             </i>
#            </p>
#            <div class="new-listing__categories">
#             <p class="new-listing__categories__category new-listing__categories__category--featured">
#              Featured
#             </p>
#             <p class="new-listing__categories__category">
#              Full-Time
#             </p>
#             <p class="new-listing__categories__category">
#              Anywhere in the World
#             </p>
#            </div>
#           </div>
#          </a>
#         </li>
#         <script>
#          document.addEventListener('DOMContentLoaded', function() {
#     // When the modal is clicked
#     var clickableElement = document.querySelector('.clickable-element');
#     if (clickableElement) {
#       clickableElement.addEventListener('click', function() {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'none';
#         }
#       });
#     }
#
#     // When the modal is closed
#     var modal = document.querySelector('.modal');
#     if (modal) {
#       modal.addEventListener('hidden.bs.modal', function () {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'block';
#         }
#       });
#     }
#   });
#         </script>
#         <li class="new-listing-container feature">
#          <div class="highlight-bar">
#          </div>
#          <div class="tooltip--flag-logo">
#           <a href="/company/files-com">
#            <div alt="Files.com is hiring a remote UI/UX Designer at We Work Remotely." class="tooltip--flag-logo__flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/5067/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)">
#            </div>
#            <span class="tooltip--flag-logo__tooltiptext">
#             View Company Profile
#            </span>
#           </a>
#          </div>
#          <a href="/remote-jobs/files-com-ui-ux-designer-2">
#           <div class="new-listing paid-logo">
#            <div class="new-listing__header">
#             <h4 class="new-listing__header__title">
#              UI/UX Designer
#             </h4>
#             <div class="new-listing__header__icons">
#              <p class="new-listing__header__icons__date">
#               6d
#              </p>
#              <img alt="Pin Icon" class="new-listing__header__icons__pinnedIcon" src="https://weworkremotely.com/assets/pin-new-listing-icon-5020930338642c85166c5dc90e0cc3b616195333121663c6dd985fe502f1466a.svg"/>
#             </div>
#            </div>
#            <p class="new-listing__company-name">
#             Files.com
#             <img alt="Star Icon" class="lis-container__job__sidebar__companyDetails__info__title__icon" src="https://weworkremotely.com/assets/company-name-new-listing-icon-899e2740e328cbba3a77a60510295001f767aae8cde67202b9157ed79be205cc.svg"/>
#            </p>
#            <p class="new-listing__company-headquarters">
#             Scottsdale, AZ
#             <i class="fa-solid fa-location-dot">
#             </i>
#            </p>
#            <div class="new-listing__categories">
#             <p class="new-listing__categories__category new-listing__categories__category--featured">
#              Featured
#             </p>
#             <p class="new-listing__categories__category">
#              Full-Time
#             </p>
#             <p class="new-listing__categories__category">
#              North America Only
#             </p>
#            </div>
#           </div>
#          </a>
#         </li>
#         <script>
#          document.addEventListener('DOMContentLoaded', function() {
#     // When the modal is clicked
#     var clickableElement = document.querySelector('.clickable-element');
#     if (clickableElement) {
#       clickableElement.addEventListener('click', function() {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'none';
#         }
#       });
#     }
#
#     // When the modal is closed
#     var modal = document.querySelector('.modal');
#     if (modal) {
#       modal.addEventListener('hidden.bs.modal', function () {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'block';
#         }
#       });
#     }
#   });
#         </script>
#         <li class="new-listing-container feature">
#          <div class="highlight-bar">
#          </div>
#          <div class="tooltip--flag-logo">
#           <a href="/company/used-conex-llc">
#            <div alt="Used Conex LLC is hiring a remote Entry Level Sales Agent - Chat Only - Side Hustle at We Work Remotely." class="tooltip--flag-logo__flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0144/3513/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)">
#            </div>
#            <span class="tooltip--flag-logo__tooltiptext">
#             View Company Profile
#            </span>
#           </a>
#          </div>
#          <a href="/remote-jobs/used-conex-llc-entry-level-sales-agent-chat-only-side-hustle">
#           <div class="new-listing paid-logo">
#            <div class="new-listing__header">
#             <h4 class="new-listing__header__title">
#              Entry Level Sales Agent - Chat Only - Side Hustle
#             </h4>
#             <div class="new-listing__header__icons">
#              <p class="new-listing__header__icons__date">
#               7d
#              </p>
#              <img alt="Pin Icon" class="new-listing__header__icons__pinnedIcon" src="https://weworkremotely.com/assets/pin-new-listing-icon-5020930338642c85166c5dc90e0cc3b616195333121663c6dd985fe502f1466a.svg"/>
#             </div>
#            </div>
#            <p class="new-listing__company-name">
#             Used Conex LLC
#             <img alt="Star Icon" class="lis-container__job__sidebar__companyDetails__info__title__icon" src="https://weworkremotely.com/assets/company-name-new-listing-icon-899e2740e328cbba3a77a60510295001f767aae8cde67202b9157ed79be205cc.svg"/>
#            </p>
#            <p class="new-listing__company-headquarters">
#             Tampa, FL
#             <i class="fa-solid fa-location-dot">
#             </i>
#            </p>
#            <div class="new-listing__categories">
#             <p class="new-listing__categories__category new-listing__categories__category--featured">
#              Featured
#             </p>
#             <p class="new-listing__categories__category">
#              Contract
#             </p>
#             <p class="new-listing__categories__category">
#              USA Only
#             </p>
#            </div>
#           </div>
#          </a>
#         </li>
#         <script>
#          document.addEventListener('DOMContentLoaded', function() {
#     // When the modal is clicked
#     var clickableElement = document.querySelector('.clickable-element');
#     if (clickableElement) {
#       clickableElement.addEventListener('click', function() {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'none';
#         }
#       });
#     }
#
#     // When the modal is closed
#     var modal = document.querySelector('.modal');
#     if (modal) {
#       modal.addEventListener('hidden.bs.modal', function () {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'block';
#         }
#       });
#     }
#   });
#         </script>
#         <li class="new-listing-container feature">
#          <div class="highlight-bar">
#          </div>
#          <div class="tooltip--flag-logo">
#           <a href="/company/toggl">
#            <div alt="Toggl is hiring a remote Senior Product Designer at We Work Remotely." class="tooltip--flag-logo__flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0074/7274/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)">
#            </div>
#            <span class="tooltip--flag-logo__tooltiptext">
#             View Company Profile
#            </span>
#           </a>
#          </div>
#          <a href="/remote-jobs/toggl-senior-product-designer-2">
#           <div class="new-listing paid-logo">
#            <div class="new-listing__header">
#             <h4 class="new-listing__header__title">
#              Senior Product Designer
#             </h4>
#             <div class="new-listing__header__icons">
#              <p class="new-listing__header__icons__date">
#               10d
#              </p>
#              <img alt="Pin Icon" class="new-listing__header__icons__pinnedIcon" src="https://weworkremotely.com/assets/pin-new-listing-icon-5020930338642c85166c5dc90e0cc3b616195333121663c6dd985fe502f1466a.svg"/>
#             </div>
#            </div>
#            <p class="new-listing__company-name">
#             Toggl
#             <img alt="Star Icon" class="lis-container__job__sidebar__companyDetails__info__title__icon" src="https://weworkremotely.com/assets/company-name-new-listing-icon-899e2740e328cbba3a77a60510295001f767aae8cde67202b9157ed79be205cc.svg"/>
#            </p>
#            <p class="new-listing__company-headquarters">
#             Tallin
#             <i class="fa-solid fa-location-dot">
#             </i>
#            </p>
#            <div class="new-listing__categories">
#             <p class="new-listing__categories__category new-listing__categories__category--featured">
#              Featured
#             </p>
#             <p class="new-listing__categories__category new-listing__categories__category--top-company">
#              <i class="fa-regular fa-star">
#              </i>
#              Top 100
#             </p>
#             <p class="new-listing__categories__category">
#              Full-Time
#             </p>
#             <p class="new-listing__categories__category">
#              $50,000 - $74,999 USD
#             </p>
#             <p class="new-listing__categories__category">
#              Anywhere in the World
#             </p>
#            </div>
#           </div>
#          </a>
#         </li>
#         <script>
#          document.addEventListener('DOMContentLoaded', function() {
# ...
#            </div>
#            <span class="tooltip--flag-logo__tooltiptext">
#             View Company Profile
#            </span>
#           </a>
#          </div>
#          <a href="/remote-jobs/skycatchfire-senior-django-developer">
#           <div class="new-listing paid-logo">
#            <div class="new-listing__header">
#             <h4 class="new-listing__header__title">
#              Senior Django Developer
#             </h4>
#             <div class="new-listing__header__icons">
#              <p class="new-listing__header__icons__date">
#               22d
#              </p>
#              <img alt="Pin Icon" class="new-listing__header__icons__pinnedIcon" src="https://weworkremotely.com/assets/pin-new-listing-icon-5020930338642c85166c5dc90e0cc3b616195333121663c6dd985fe502f1466a.svg"/>
#             </div>
#            </div>
#            <p class="new-listing__company-name">
#             SKYCATCHFIRE
#             <img alt="Star Icon" class="lis-container__job__sidebar__companyDetails__info__title__icon" src="https://weworkremotely.com/assets/company-name-new-listing-icon-899e2740e328cbba3a77a60510295001f767aae8cde67202b9157ed79be205cc.svg"/>
#            </p>
#            <p class="new-listing__company-headquarters">
#             Canton, Ohio
#             <i class="fa-solid fa-location-dot">
#             </i>
#            </p>
#            <div class="new-listing__categories">
#             <p class="new-listing__categories__category new-listing__categories__category--pro">
#              Pro
#             </p>
#             <p class="new-listing__categories__category">
#              Full-Time
#             </p>
#             <p class="new-listing__categories__category">
#              $100,000 or more USD
#             </p>
#             <p class="new-listing__categories__category">
#              USA Only
#             </p>
#            </div>
#           </div>
#          </a>
#         </li>
#         <script>
#          document.addEventListener('DOMContentLoaded', function() {
#     // When the modal is clicked
#     var clickableElement = document.querySelector('.clickable-element');
#     if (clickableElement) {
#       clickableElement.addEventListener('click', function() {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'none';
#         }
#       });
#     }
#
#     // When the modal is closed
#     var modal = document.querySelector('.modal');
#     if (modal) {
#       modal.addEventListener('hidden.bs.modal', function () {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'block';
#         }
#       });
#     }
#   });
#         </script>
#         <li class="new-listing-container feature">
#          <div class="highlight-bar">
#          </div>
#          <div class="tooltip--flag-logo">
#           <a href="/company/neris-analytics-limited">
#            <div alt="NERIS Analytics Limited is hiring a remote Experienced Backend Developer (Laravel/Vue) at We Work Remotely." class="tooltip--flag-logo__flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0083/2555/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)">
#            </div>
#            <span class="tooltip--flag-logo__tooltiptext">
#             View Company Profile
#            </span>
#           </a>
#          </div>
#          <a href="/remote-jobs/neris-analytics-limited-experienced-backend-developer-laravel-vue">
#           <div class="new-listing paid-logo">
#            <div class="new-listing__header">
#             <h4 class="new-listing__header__title">
#              Experienced Backend Developer (Laravel/Vue)
#             </h4>
#             <div class="new-listing__header__icons">
#              <p class="new-listing__header__icons__date">
#               24d
#              </p>
#             </div>
#            </div>
#            <p class="new-listing__company-name">
#             NERIS Analytics Limited
#             <img alt="Star Icon" class="lis-container__job__sidebar__companyDetails__info__title__icon" src="https://weworkremotely.com/assets/company-name-new-listing-icon-899e2740e328cbba3a77a60510295001f767aae8cde67202b9157ed79be205cc.svg"/>
#            </p>
#            <p class="new-listing__company-headquarters">
#             Cambridge, United Kingdom
#             <i class="fa-solid fa-location-dot">
#             </i>
#            </p>
#            <div class="new-listing__categories">
#             <p class="new-listing__categories__category">
#              Full-Time
#             </p>
#             <p class="new-listing__categories__category">
#              $75,000 - $99,999 USD
#             </p>
#             <p class="new-listing__categories__category">
#              Anywhere in the World
#             </p>
#            </div>
#           </div>
#          </a>
#         </li>
#         <script>
#          document.addEventListener('DOMContentLoaded', function() {
#     // When the modal is clicked
#     var clickableElement = document.querySelector('.clickable-element');
#     if (clickableElement) {
#       clickableElement.addEventListener('click', function() {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'none';
#         }
#       });
#     }
#
#     // When the modal is closed
#     var modal = document.querySelector('.modal');
#     if (modal) {
#       modal.addEventListener('hidden.bs.modal', function () {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'block';
#         }
#       });
#     }
#   });
#         </script>
#         <li class="new-listing-container">
#          <div class="">
#          </div>
#          <div class="tooltip--flag-logo">
#           <a href="/company/hostaway-opco-oy">
#            <div alt="Hostaway Opco Oy is hiring a remote Engineering Technical Lead - Node.js - EMEA at We Work Remotely." class="tooltip--flag-logo__flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0136/4009/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)">
#            </div>
#            <span class="tooltip--flag-logo__tooltiptext">
#             View Company Profile
#            </span>
#           </a>
#          </div>
#          <a href="/remote-jobs/hostaway-engineering-technical-lead-node-js-emea-1">
#           <div class="new-listing paid-logo">
#            <div class="new-listing__header">
#             <h4 class="new-listing__header__title">
#              Engineering Technical Lead - Node.js - EMEA
#             </h4>
#             <div class="new-listing__header__icons">
#              <p class="new-listing__header__icons__date">
#               25d
#              </p>
#             </div>
#            </div>
#            <p class="new-listing__company-name">
#             Hostaway Opco Oy
#             <img alt="Star Icon" class="lis-container__job__sidebar__companyDetails__info__title__icon" src="https://weworkremotely.com/assets/company-name-new-listing-icon-899e2740e328cbba3a77a60510295001f767aae8cde67202b9157ed79be205cc.svg"/>
#            </p>
#            <p class="new-listing__company-headquarters">
#             Finland
#             <i class="fa-solid fa-location-dot">
#             </i>
#            </p>
#            <div class="new-listing__categories">
#             <p class="new-listing__categories__category">
#              Full-Time
#             </p>
#             <p class="new-listing__categories__category">
#              EMEA Only
#             </p>
#            </div>
#           </div>
#          </a>
#         </li>
#         <script>
#          document.addEventListener('DOMContentLoaded', function() {
#     // When the modal is clicked
#     var clickableElement = document.querySelector('.clickable-element');
#     if (clickableElement) {
#       clickableElement.addEventListener('click', function() {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'none';
#         }
#       });
#     }
#
#     // When the modal is closed
#     var modal = document.querySelector('.modal');
#     if (modal) {
#       modal.addEventListener('hidden.bs.modal', function () {
#         var navHeader = document.querySelector('#nav-header');
#         if (navHeader) {
#           navHeader.style.display = 'block';
#         }
#       });
#     }
#   });
#         </script>
#         <li class="view-all">
#          <a href="/categories/remote-back-end-programming-jobs">
#           View all 26 Back-End Programming jobs
#          </a>
#         </li>
#        </ul>
#       </article>
#      </section>
#     </div>
#     <br style="clear:both"/>
#     <script>
#      if ( document.getElementById('error_explanation')){
#     document.getElementById('error_explanation').style.display = 'none';
#   }
#   if ( document.getElementById('successExplanation')){
#     document.getElementById('successExplanation').style.display = 'none';
#   }
#     </script>
#    </div>
#   </div>
#   <footer class="footer">
#    <section class="footer__top">
#     <div class="footer__top__logo">
#      <a href="#">
#       <img id="footer-logo-v2" src="https://weworkremotely.com/assets/LogoV1@2x-ed59a6afefa9602e4609287a371d61e114cf284c72976ebcef43444c35a0db64.png"/>
#      </a>
#     </div>
#     <div class="footer__top__links">
#      <a href="/top-remote-companies">
#       Top 100 Companies
#      </a>
#      <a href="/blog">
#       Blog
#      </a>
#      <a href="/frequently-asked-questions">
#       FAQ - Employers
#      </a>
#      <a href="/blog-categories/events" target="_blank">
#       Events
#      </a>
#      <a href="/remote-job-rss-feed">
#       RSS
#      </a>
#     </div>
#     <div class="footer__top__jobs-counter">
#      <i class="footer__top__jobs-counter__icon fa-sharp fa-light fa-fire" style="color: #F03F3F;">
#      </i>
#      <p class="footer__top__jobs-counter__number">
#       34,136
#       <span>
#        Remote jobs posted
#       </span>
#      </p>
#     </div>
#    </section>
#    <section class="footer__bottom">
#     <div class="footer__bottom__copyright desktop-only">
#      © 2025 We Work Remotely
#     </div>
#     <div class="footer__bottom__ancher">
#      <div class="footer__bottom__ancher--links">
#       <div class="footer__bottom__copyright--mobile mobile-only">
#        © 2025 We Work Remotely
#       </div>
#       <a href="/cdn-cgi/l/email-protection#a8dbddd8d8c7dadce8dfcddfc7dac3dacdc5c7dccdc4d186cbc7c5" target="_blank">
#        Contact Support
#       </a>
#       <a href="/terms-and-conditions">
#        Terms
#       </a>
#       <a href="/community-guidelines">
#        Guidelines
#       </a>
#       <br class="mobile-only"/>
#       <a href="/privacy">
#        Privacy
#       </a>
#       <a href="/post-a-remote-job">
#        Why Choose WWR?
#       </a>
#      </div>
#      <div class="footer__bottom__ancher--socials">
#       <a href="https://www.facebook.com/weworkremotely/?utm_content=footer-network&amp;utm_source=we-work-remotely&amp;utm_campaign=footer-network-fb&amp;utm_medium=footer-network-fb" target="_blank">
#        <i class="fa-brands fa-square-facebook fa-2x">
#        </i>
#       </a>
#       <a href="https://www.linkedin.com/company/18527028/?utm_content=footer-network&amp;utm_source=we-work-remotely&amp;utm_campaign=footer-network-linkedin&amp;utm_medium=footer-network-linkedin" target="_blank">
#        <i class="fa-brands fa-linkedin fa-2x">
#        </i>
#       </a>
#       <a href="https://www.instagram.com/weworkremotelycom/?hl=en&amp;utm_campaign=footer-network-ig&amp;utm_medium=footer-network-ig" target="_blank">
#        <i class="fa-brands fa-square-instagram fa-2x">
#        </i>
#       </a>
#       <a href="https://twitter.com/weworkremotely/?utm_content=footer-network&amp;utm_source=we-work-remotely&amp;utm_campaign=footer-network-twitter&amp;utm_medium=footer-network-twitter" target="_blank">
#        <i class="fa-brands fa-x-twitter fa-2x">
#        </i>
#       </a>
#      </div>
#     </div>
#    </section>
#   </footer>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script src="https://code.jquery.com/jquery-3.5.1.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-ujs/1.2.2/rails.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/fixto/0.5.0/fixto.min.js">
#   </script>
#   <script src="https://unpkg.com/@popperjs/core@2">
#   </script>
#   <script src="https://unpkg.com/tippy.js@6">
#   </script>
#   <script>
#    tippy('.clip-btn', {
#     content: "Email Copied to Clipboard!",
#     placement: 'top',
#     animation: 'fade',
#     trigger: 'click',
#     delay: 50,
#     // onShow(instance) {
#     //   setTimeout(() => {
#     //     instance.hide();
#     //   }, 5000);
#     // }
#   });
#   </script>
#   <script src="https://weworkremotely.com/assets/application_minimal-e6a7e3f100d19c0986345a9973828d5684dd77d360516bf751f7e5d06532017a.js">
#   </script>
#   <script async="">
#    adroll_adv_id="ACJ6YJHXKNBNJBSFTNFVOF",adroll_pix_id="W4DPE7ODW5E3BKBBL3VPMG",adroll_email="matt@tinyboards.co",function(){var t=function(){if(!document.readyState||/loaded|complete/.test(document.readyState)){if(!window.__adroll_loaded)return __adroll_loaded=!0,void setTimeout(t,50);var e=document.createElement("script"),d="https:"==document.location.protocol?"https://s.adroll.com":"http://a.adroll.com";e.setAttribute("async","true"),e.type="text/javascript",e.src=d+"/j/roundtrip.js",((document.getElementsByTagName("head")||[null])[0]||document.getElementsByTagName("script")[0].parentNode).appendChild(e)}else setTimeout(t,10)};window.addEventListener?window.addEventListener("load",t,!1):window.attachEvent("onload",t)}();
#   </script>
#   <script async="">
#    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
# },s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='//static.ads-twitter.com/uwt.js',
# a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
# // Insert Twitter Pixel ID and Standard Event data below
# twq('init','nzx8k');
# twq('track','PageView');
#   </script>
#   <script>
#    _linkedin_partner_id = "663722"; window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || []; window._linkedin_data_partner_ids.push(_linkedin_partner_id);
#   </script>
#   <script>
#    (function(){var s = document.getElementsByTagName("script")[0]; var b = document.createElement("script"); b.type = "text/javascript";b.async = true; b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js"; s.parentNode.insertBefore(b, s);})();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=663722&amp;fmt=gif" style="display:none;" width="1"/>
#   </noscript>
#   <script crossorigin="anonymous" integrity="sha512-rMGGF4wg1R73ehtnxXBt5mbUfN9JUJwbk21KMlnLZDJh7BkPmeovBuddZCENJddHYYMkCh9hPFnPmS9sspki8g==" src="https://cdnjs.cloudflare.com/ajax/libs/chosen/1.8.7/chosen.jquery.min.js">
#   </script>
#   <script>
#    jQuery(document).ready(function () {
#     var chosenOpen = false;
#     jQuery(".chosen").chosen();
#     jQuery('.outsider-select').append('<span class="closeChosen"></span>');
#     jQuery(document).on('click', '.closeChosen', function (e) {
#       var chosenEle = jQuery(this).parents('.outsider-select').find('.chosen-container');
#       if (chosenEle.hasClass('chosen-with-drop') && chosenEle.hasClass('chosen-container-active')) {
#         jQuery(this).parents('.outsider-select').find('select').trigger('chosen:close');
#       } else {
#         jQuery(this).parents('.outsider-select').find('select').trigger('chosen:open');
#       }
#     });
#
#     // Warning - Library is no longer maintained, refer: https://github.com/bbarakaci/fixto
#     // Update Library to https://cdnjs.com/libraries/stickybits
#     var stickyEl = jQuery('#advanced_search_filters').fixTo('#side_filter_column', {
#       top: 100,
#       mindBottomPadding: true
#     });
#   });
#   </script>
#  </body>
# </html>

# %%
c_name = soup.find_all(class_="new-listing__company-name")
j = soup.find_all(class_="new-listing__header__title")
j_type = soup.find_all(class_="new-listing__company-headquarters")
# Out:
# Found job posts:
# https://weworkremotely.com/company/cdata-virtuality
# https://weworkremotely.com/company/files-com
# https://weworkremotely.com/company/used-conex-llc
# https://weworkremotely.com/company/toggl
# https://weworkremotely.comhttps://metana.io/full-stack-software-engineer-bootcamp/?utm_source=weworkremotely.com&utm_medium=homepage-ad
# https://weworkremotely.com/company/onthegosystems
# https://weworkremotely.com/company/the-hoyle-firm-pc
# https://weworkremotely.com/company/subscript
# https://weworkremotely.com/company/realiste
# https://weworkremotely.com/company/ixdf-interaction-design-foundation
# https://weworkremotely.com/company/chameleon
# https://weworkremotely.com/company/spiralyze
# https://weworkremotely.com/company/michael-findeisen-consulting
# https://weworkremotely.com/company/6-figure-creative
# https://weworkremotely.com/company/almabase
# https://weworkremotely.com/company/patchstack
# https://weworkremotely.com/company/close
# https://weworkremotely.com/company/nogigiddy
# https://weworkremotely.com/company/wp-all-import
# https://weworkremotely.com/company/community-phone
# https://weworkremotely.com/company/royal-moving-storage-inc
# https://weworkremotely.com/company/vidpros
# https://weworkremotely.com/company/lathire
# https://weworkremotely.com/company/toast
# https://weworkremotely.com/company/salesflow-io
# https://weworkremotely.com/company/report-owl-llc
# https://weworkremotely.com/company/usedconex-com
# https://weworkremotely.com/company/real-mushrooms
# https://weworkremotely.com/company/skyline-management-gmbh
# https://weworkremotely.com/company/simon-miccio-miccio
# https://weworkremotely.com/company/hygraph
# https://weworkremotely.com/company/loop-support
# https://weworkremotely.com/company/stone-creek-global
# https://weworkremotely.com/company/lawnstarter
# https://weworkremotely.com/company/veria
# https://weworkremotely.com/company/veria
# https://weworkremotely.com/company/float
# https://weworkremotely.com/company/zanda-health
# https://weworkremotely.com/company/adept-consulting-services-inc
# https://weworkremotely.com/company/soflyy
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/telus-international-ai-inc
# https://weworkremotely.com/company/dataannotation-tech
# https://weworkremotely.com/company/native-camp
# https://weworkremotely.com/company/prowritersites
# https://weworkremotely.com/company/ewu-media-llc
# https://weworkremotely.com/company/pr-volt
# https://weworkremotely.com/company/alfanoos-international-ltd
# https://weworkremotely.com/company/the-sher-agency
# https://weworkremotely.com/company/kake
# https://weworkremotely.com/company/northwrd
# https://weworkremotely.com/company/altitude
# https://weworkremotely.com/company/bewriters
# https://weworkremotely.com/company/stiebler-commerce
# https://weworkremotely.com/company/pr-volt
# https://weworkremotely.com/company/growthx
# https://weworkremotely.com/company/lathire
# https://weworkremotely.com/company/quizgecko-com
# https://weworkremotely.com/company/simplyanalytics
# https://weworkremotely.com/company/close
# https://weworkremotely.com/company/volatus-health
# https://weworkremotely.com/company/speechify-inc
# https://weworkremotely.com/company/speechify-inc
# https://weworkremotely.com/company/breakthrough-design-group
# https://weworkremotely.com/company/soar-financials
# https://weworkremotely.com/company/constable-co-uk
# https://weworkremotely.com/company/maharishi-foundation-international
# https://weworkremotely.com/company/skycatchfire
# https://weworkremotely.com/company/bitovi
# https://weworkremotely.com/company/doximity
# https://weworkremotely.com/company/paperpile
# https://weworkremotely.com/company/paperpile
# https://weworkremotely.com/company/speechify-inc
# https://weworkremotely.com/company/chameleon
# https://weworkremotely.com/company/onthegosystems
# https://weworkremotely.com/company/onthegosystems
# https://weworkremotely.com/company/mdcalc
# https://weworkremotely.com/company/paymentology
# https://weworkremotely.com/company/elite-software-automation
# https://weworkremotely.com/company/outlier-ai
# https://weworkremotely.com/company/outlier-ai
# https://weworkremotely.com/company/outlier-ai
# https://weworkremotely.com/company/lemon-io
# https://weworkremotely.com/company/onthegosystems
# https://weworkremotely.com/company/lifeanalytics
# https://weworkremotely.com/company/vanta
# https://weworkremotely.com/company/learning-tapestry
# https://weworkremotely.com/company/subscript
# https://weworkremotely.com/company/platform-engineering-labs
# https://weworkremotely.com/company/freeman-s-hindman
# https://weworkremotely.com/company/mailerlite
# https://weworkremotely.com/company/ixdf-interaction-design-foundation
# https://weworkremotely.com/company/edge-network
# https://weworkremotely.com/company/elevate-labs
# https://weworkremotely.com/company/codesignal
# https://weworkremotely.com/company/motomate123
# https://weworkremotely.com/company/the-sher-agency
# https://weworkremotely.com/company/distrokid
# https://weworkremotely.com/company/dakoda-ai
# https://weworkremotely.com/company/canonical
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/proxify-ab
# https://weworkremotely.com/company/lemon-io
# https://weworkremotely.com/company/pagos-ai
# https://weworkremotely.com/company/discord
# https://weworkremotely.com/company/creative-force
# https://weworkremotely.com/company/baxenergy
# https://weworkremotely.com/company/relay-commerce
# https://weworkremotely.com/company/remotemore
# https://weworkremotely.com/company/discogs-inc
# https://weworkremotely.com/company/cdata-software
# https://weworkremotely.com/company/omni-interactions
# https://weworkremotely.com/company/nogigiddy
# https://weworkremotely.com/company/tiller
# https://weworkremotely.com/company/clustdoc
# https://weworkremotely.com/company/htl-recruits
# https://weworkremotely.com/company/mozio
# https://weworkremotely.com/company/your-insurance-license-llc
# https://weworkremotely.com/company/veria
# https://weworkremotely.com/company/working-solutions
# https://weworkremotely.com/company/gemcommerce
# https://weworkremotely.com/company/relay-commerce
# https://weworkremotely.com/company/storeganise
# https://weworkremotely.com/company/creative-force
# https://weworkremotely.com/company/the-ward-law-group
# https://weworkremotely.com/company/breedj
# https://weworkremotely.com/company/nogigiddy
# https://weworkremotely.com/company/nogigiddy
# https://weworkremotely.com/company/clipboard-health
# https://weworkremotely.com/company/filestage
# https://weworkremotely.com/company/nogigiddy
# https://weworkremotely.com/company/leadsimple-inc
# https://weworkremotely.com/company/brightorder-inc
# https://weworkremotely.com/company/elite-software-automation
# https://weworkremotely.com/company/instacart
# https://weworkremotely.com/company/abnormal-security
# https://weworkremotely.com/company/cresta
# https://weworkremotely.com/company/pie-insurance
# https://weworkremotely.com/company/doordash
# https://weworkremotely.com/company/clipboard-health
# https://weworkremotely.com/company/close
# https://weworkremotely.com/company/plex
# https://weworkremotely.com/company/datadog
# https://weworkremotely.com/company/clipboard-health
# https://weworkremotely.com/company/startree
# https://weworkremotely.com/company/affirm
# https://weworkremotely.com/company/cribl
# https://weworkremotely.com/company/real-mushrooms
# https://weworkremotely.com/company/sensic
# https://weworkremotely.com/company/sanctuary-computer-garden3d
# https://weworkremotely.com/company/sbs-expedited-services-ltd
# https://weworkremotely.com/company/northstar-finance-llc
# https://weworkremotely.com/company/mediabuyer-com
# https://weworkremotely.com/company/soar-financials
# https://weworkremotely.com/company/maverick-trading
# https://weworkremotely.com/company/spiralyze
# https://weworkremotely.com/company/adams-hr-group-llc
# https://weworkremotely.com/company/soar-financials
# https://weworkremotely.com/company/tailscale
# https://weworkremotely.com/company/wordwall
# https://weworkremotely.com/company/soar-financials
# https://weworkremotely.com/company/toggl
# https://weworkremotely.com/company/wealthbox-crm
# https://weworkremotely.com/company/a-team
# https://weworkremotely.com/company/bitovi
# https://weworkremotely.com/company/scholarshipowl
# https://weworkremotely.com/company/clickguard-inc
# https://weworkremotely.com/company/hivemq
# https://weworkremotely.com/company/toggl
# https://weworkremotely.com/company/onthegosystems
# https://weworkremotely.com/company/proton-ai
# https://weworkremotely.com/company/edge-network
# https://weworkremotely.com/company/float
# https://weworkremotely.com/company/source
# https://weworkremotely.com/company/hygraph
# https://weworkremotely.com/company/float
# https://weworkremotely.com/company/close
# https://weworkremotely.com/company/filestage
# https://weworkremotely.com/company/volatus-health
# https://weworkremotely.com/company/semaphore
# https://weworkremotely.com/company/sanctuary-computer
# https://weworkremotely.com/company/bitovi
# https://weworkremotely.com/company/speechify-inc
# https://weworkremotely.com/company/wisnam
# https://weworkremotely.com/company/soar-financials
# https://weworkremotely.com/company/manual
# https://weworkremotely.com/company/silverfin
# https://weworkremotely.com/company/silverfin
# https://weworkremotely.com/company/silverfin
# https://weworkremotely.com/company/everyonesocial
# https://weworkremotely.com/company/scalable-path
# https://weworkremotely.com/company/skycatchfire
# https://weworkremotely.com/company/neris-analytics-limited
# https://weworkremotely.com/company/hostaway-opco-oy

# %%
company_name = []
for job in c_name:
  if job:
    company_name.append(job.get_text(strip=True))
  else:
        company_name.append(None)


job_title = []
for t in j :
 if t:
    job_title.append(t.get_text(strip=True))
 else:
    job_title.append(None)
 
job_links = []
div_class = "jobs-listing"  # Replace with the specific class you want to search for
    
    # Loop through the divs containing the links
for div in soup.find_all('div', class_="tooltip--flag-logo"):
        link = div.find('a', href=True)
        if link:
            job_links.append(link['href'])

# %%
data = {
    'company name': company_name,
    'Job Title': job_title,
    'Link': [f"https://weworkremotely.com{link}" for link in job_links]

}

# Step 5: Create the DataFrame
df = pd.DataFrame(data)

# Step 6: Display the DataFrame
df.head(201)
# Out:
#                 company name  \
# 0           CData Virtuality
# 1                  Files.com
# 2             Used Conex LLC
# 3                      Toggl
# 4                     Metana
# ..                       ...
# 196           EveryoneSocial
# 197            Scalable Path
# 198             SKYCATCHFIRE
# 199  NERIS Analytics Limited
# 200         Hostaway Opco Oy
#
#                                              Job Title  \
# 0                        Senior Backend Developer SaaS
# 1                                       UI/UX Designer
# 2    Entry Level Sales Agent - Chat Only - Side Hustle
# 3                              Senior Product Designer
# 4      Coding Tech Bootcamp - Job Guaranteed by Metana
# ..                                                 ...
# 196  Backend Engineer (profitable startup, veteran ...
# 197           Machine Learning Engineer for Agentic AI
# 198                            Senior Django Developer
# 199        Experienced Backend Developer (Laravel/Vue)
# 200        Engineering Technical Lead - Node.js - EMEA
#
#                                                   Link
# 0    https://weworkremotely.com/company/cdata-virtu...
# 1         https://weworkremotely.com/company/files-com
# 2    https://weworkremotely.com/company/used-conex-llc
# 3             https://weworkremotely.com/company/toggl
# 4    https://weworkremotely.comhttps://metana.io/fu...
# ..                                                 ...
# 196  https://weworkremotely.com/company/everyonesocial
# 197   https://weworkremotely.com/company/scalable-path
# 198    https://weworkremotely.com/company/skycatchfire
# 199  https://weworkremotely.com/company/neris-analy...
# 200  https://weworkremotely.com/company/hostaway-op...
#
# [201 rows x 3 columns]
